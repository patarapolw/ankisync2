# %%
from ankisync2.anki import Apkg

apkg = iter(Apkg("/Users/patarapolw/Downloads/Hanyu_Shuiping_Kaoshi_HSK_all_5000_words_high_quality.apkg"))

for i in range(5):
    print(i)
    display(next(apkg))
# Out:
# 0
# {'id': 1,
#  'note': {'id': 1,
#   'guid': 'd3/P6`]Th(',
#   'model': {'id': 1425274727596,
#    'name': 'HSK',
#    'flds': ['Simplified',
#     'Traditional',
#     'Pinyin',
#     'English',
#     'Classifier',
#     'Taiwan Pinyin',
#     'Words With Same Pinyin'],
# ...
